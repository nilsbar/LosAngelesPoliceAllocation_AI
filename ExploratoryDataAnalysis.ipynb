# %%
# imports
import pandas as pd
import numpy as np

# %% [markdown]
# ### Data preparation

# %%
# create the DataFrames
crime_rate_2010_to_2019_df = pd.read_csv("data\Crime_Data_from_2010_to_2019_20231222.csv")
crime_rate_2020_to_2023_df = pd.read_csv("data\Crime_Data_from_2020_to_Present_20231222.csv")
LAPD_calls_2020_df = pd.read_csv("data\LAPD_Calls_for_Service_2020_20231222.csv")
LAPD_calls_2021_df = pd.read_csv("data\LAPD_Calls_for_Service_2021_20231222.csv")
LAPD_calls_2022_df = pd.read_csv("data\LAPD_Calls_for_Service_2022_20231222.csv")

# %% [markdown]
# 1. Data preparation to get one crime rate DataFrame and one Service calls DataFrame

# %%
crime_rate_df = pd.concat([crime_rate_2010_to_2019_df, crime_rate_2020_to_2023_df], ignore_index=True)

# %%
LAPD_calls_df = pd.concat([LAPD_calls_2020_df, LAPD_calls_2021_df, LAPD_calls_2022_df],ignore_index=False)

# %% [markdown]
# 2. Data Quality checks

# %%
crime_rate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2993433 entries, 0 to 2993432
# Data columns (total 29 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   DR_NO           int64
#  1   Date Rptd       object
#  2   DATE OCC        object
#  3   TIME OCC        int64
#  4   AREA            float64
#  5   AREA NAME       object
#  6   Rpt Dist No     int64
#  7   Part 1-2        int64
#  8   Crm Cd          int64
#  9   Crm Cd Desc     object
#  10  Mocodes         object
#  11  Vict Age        int64
#  12  Vict Sex        object
#  13  Vict Descent    object
#  14  Premis Cd       float64
#  15  Premis Desc     object
#  16  Weapon Used Cd  float64
#  17  Weapon Desc     object
#  18  Status          object
#  19  Status Desc     object
#  20  Crm Cd 1        float64
#  21  Crm Cd 2        float64
#  22  Crm Cd 3        float64
#  23  Crm Cd 4        float64
#  24  LOCATION        object
#  25  Cross Street    object
#  26  LAT             float64
# ...

# %%
crime_rate_df.head(3)
# Out:
#       DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA   \
# 0   1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350   13.0
# 1  11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45   14.0
# 2  70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515   13.0
#
#   AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Newton         1385         2     900
# 1   Pacific         1485         2     740
# 2    Newton         1324         2     946
#
#                                          Crm Cd Desc  ...   Status Desc  \
# 0                           VIOLATION OF COURT ORDER  ...  Adult Arrest
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...   Invest Cont
# 2                          OTHER MISCELLANEOUS CRIME  ...   Invest Cont
#
#    Crm Cd 1 Crm Cd 2 Crm Cd 3  Crm Cd 4  \
# 0     900.0      NaN      NaN       NaN
# 1     740.0      NaN      NaN       NaN
# 2     946.0      NaN      NaN       NaN
#
# ...

# %%
crime_rate_df.isnull().sum()
# Out:
# DR_NO                   0
# Date Rptd               0
# DATE OCC                0
# TIME OCC                0
# AREA               857658
# AREA NAME               0
# Rpt Dist No             0
# Part 1-2                0
# Crm Cd                  0
# Crm Cd Desc             0
# Mocodes            352115
# Vict Age                0
# Vict Sex           314958
# Vict Descent       315011
# Premis Cd              57
# Premis Desc           717
# Weapon Used Cd    1978414
# Weapon Desc       1978415
# Status                  3
# Status Desc             0
# Crm Cd 1               21
# Crm Cd 2          2787544
# Crm Cd 3          2987613
# Crm Cd 4          2993263
# LOCATION                0
# Cross Street      2499025
# LAT                     0
# LON                     0
# AREA              2135775
# dtype: int64

# %% [markdown]
# Find logical explanations for the NaN-values

# %%
crime_rate_df[crime_rate_df['AREA'].isnull()]
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0          1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350
# 1         11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45
# 2         70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515
# 3         90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150
# 4        100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100
# ...            ...                     ...                     ...       ...
# 2135770  190506304  02/22/2019 12:00:00 AM  02/22/2019 12:00:00 AM       840
# 2135771  190608903  03/28/2019 12:00:00 AM  03/28/2019 12:00:00 AM       400
# 2135772  192004409  01/06/2019 12:00:00 AM  01/06/2019 12:00:00 AM      2100
# 2135773  191716777  10/17/2019 12:00:00 AM  10/16/2019 12:00:00 AM      1800
# 2135774  190805435  02/01/2019 12:00:00 AM  02/01/2019 12:00:00 AM      1615
#
# ...

# %% [markdown]
# 3. Understanding the connections between the two DataFrames

# %% [markdown]
# First hypothesis: the crimes are included in the LAPD calls (at least the crimes which can be )
